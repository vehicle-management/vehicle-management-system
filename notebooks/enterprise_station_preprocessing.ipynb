# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Enterprise Station Dataset Preprocessing

# %%
data_path = '../data/raw/enterprise_station.csv'
raw_df = pd.read_csv(data_path)

# %% [markdown]
# ## Data Summary

# %%
raw_df.head()
# Out:
#    index     tid                            loc_name loc_number loc_type  \
# 0      0  103985                    Lihue Kuhio Hwy.     LIHC61     CITY
# 1      1  103986                       Lihue Airport     LIHT61  AIRPORT
# 2      2  103987  Schofield Barracks (Military Only)     E13651     CITY
# 3      3  103988                     Molokai Airport     MKKT71  AIRPORT
# 4      4  103989                              Kailua     E13610     CITY
#
#                     address_1 country               city state  \
# 0            3-3257 Kuhio Hwy      US              Lihue    HI
# 1         3276 Hoolimalima Pl      US              Lihue    HI
# 2  694 Mccormack Ave Bldg 694      US  Schofield Barrack    HI
# 3    Bldg #2 Airport Loop Mkk      US           Hoolehua    HI
# 4             134a Hamakua Dr      US             Kailua    HI
#
#              phone  postal_code group_branch_number   latitude   longitude  \
# 0  +1 808-241-5580        96766                36EL  21.990878 -159.366127
# 1  +1 844-914-1553        96766                3642  21.979900 -159.350200
# 2  +1 808-671-5399        96786                3651  21.498478 -158.008438
# 3  +1 808-567-6381        96729                36A8  21.156484 -157.098400
# 4  +1 808-261-4282        96734                3610  21.391604 -157.743429
#
#       update_timestamp              RunDate     InsertUpdateTime  RunID  \
# 0  2022-03-25 00:00:00  2022-05-03 08:50:05  2022-05-03 08:53:49  46292
# 1  2021-05-03 00:00:00  2022-05-03 08:50:05  2022-05-03 08:53:49  46292
# 2  2022-04-06 00:00:00  2022-05-03 08:50:05  2022-05-03 08:54:09  46292
# 3  2021-10-07 00:00:00  2022-05-03 08:50:05  2022-05-03 08:55:44  46292
# 4  2022-03-25 00:00:00  2022-05-03 08:50:05  2022-05-03 08:55:55  46292
#
#         brand
# 0  ENTERPRISE
# 1  ENTERPRISE
# 2  ENTERPRISE
# 3       ALAMO
# 4  ENTERPRISE

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                4177 non-null   int64
#  1   tid                  4177 non-null   int64
#  2   loc_name             4177 non-null   object
#  3   loc_number           4177 non-null   object
#  4   loc_type             4177 non-null   object
#  5   address_1            4177 non-null   object
#  6   country              4177 non-null   object
#  7   city                 4177 non-null   object
#  8   state                4177 non-null   object
#  9   phone                4177 non-null   object
#  10  postal_code          4177 non-null   int64
#  11  group_branch_number  4177 non-null   object
#  12  latitude             4177 non-null   float64
#  13  longitude            4177 non-null   float64
#  14  update_timestamp     4177 non-null   object
#  15  RunDate              4177 non-null   object
#  16  InsertUpdateTime     4177 non-null   object
#  17  RunID                4177 non-null   int64
#  18  brand                4177 non-null   object
# dtypes: float64(2), int64(4), object(13)
# memory usage: 620.1+ KB

# %%
raw_df.describe(include='all')
# Out:
#               index            tid loc_name loc_number loc_type  address_1  \
# count   4177.000000    4177.000000     4177       4177     4177       4177
# unique          NaN            NaN     3923       4177        5       4086
# top             NaN            NaN  Madison     LIHC61     CITY  1 Glen Rd
# freq            NaN            NaN        7          1     3691          3
# mean    2088.000000  106073.000000      NaN        NaN      NaN        NaN
# std     1205.940366    1205.940366      NaN        NaN      NaN        NaN
# min        0.000000  103985.000000      NaN        NaN      NaN        NaN
# 25%     1044.000000  105029.000000      NaN        NaN      NaN        NaN
# 50%     2088.000000  106073.000000      NaN        NaN      NaN        NaN
# 75%     3132.000000  107117.000000      NaN        NaN      NaN        NaN
# max     4176.000000  108161.000000      NaN        NaN      NaN        NaN
#
#        country     city state            phone   postal_code  \
# count     4177     4177  4177             4177   4177.000000
# unique       1     2251    52             4035           NaN
# top         US  Houston    CA  +1 214-688-4396           NaN
# freq      4177       50   421                7           NaN
# mean       NaN      NaN   NaN              NaN  49634.113239
# std        NaN      NaN   NaN              NaN  29707.040714
# min        NaN      NaN   NaN              NaN    603.000000
# 25%        NaN      NaN   NaN              NaN  25414.000000
# 50%        NaN      NaN   NaN              NaN  45014.000000
# 75%        NaN      NaN   NaN              NaN  77450.000000
# max        NaN      NaN   NaN              NaN  99801.000000
#
#        group_branch_number     latitude    longitude     update_timestamp  \
# count                 4177  4177.000000  4177.000000                 4177
# unique                4177          NaN          NaN                  442
# top                   36EL          NaN          NaN  2022-04-19 00:00:00
# freq                     1          NaN          NaN                  144
# mean                   NaN    36.999051   -91.196025                  NaN
# std                    NaN     5.448131    16.467218                  NaN
# min                    NaN    18.005940  -159.366127                  NaN
# 25%                    NaN    33.554220   -97.600942                  NaN
# 50%                    NaN    37.864800   -86.111582                  NaN
# 75%                    NaN    40.900747   -79.431661                  NaN
# max                    NaN    64.817786   -65.666966                  NaN
#
#                     RunDate     InsertUpdateTime    RunID       brand
# count                  4177                 4177   4177.0        4177
# unique                    1                 1145      NaN           3
# top     2022-05-03 08:50:05  2022-05-03 14:12:16      NaN  ENTERPRISE
# freq                   4177                   55      NaN        4171
# mean                    NaN                  NaN  46292.0         NaN
# std                     NaN                  NaN      0.0         NaN
# min                     NaN                  NaN  46292.0         NaN
# 25%                     NaN                  NaN  46292.0         NaN
# 50%                     NaN                  NaN  46292.0         NaN
# 75%                     NaN                  NaN  46292.0         NaN
# max                     NaN                  NaN  46292.0         NaN

# %%
missing_values = raw_df.isnull().sum()
print("Missing or null values in each column:\n", missing_values)
# Out:
# Missing or null values in each column:
#  index                  0
# tid                    0
# loc_name               0
# loc_number             0
# loc_type               0
# address_1              0
# country                0
# city                   0
# state                  0
# phone                  0
# postal_code            0
# group_branch_number    0
# latitude               0
# longitude              0
# update_timestamp       0
# RunDate                0
# InsertUpdateTime       0
# RunID                  0
# brand                  0
# dtype: int64

# %% [markdown]
# #### Dropping Missing Values
# Since there are no columns with null values, no further processing is needed.

# %%
cleaned_df = raw_df
cleaned_df
# Out:
#       index     tid                            loc_name loc_number loc_type  \
# 0         0  103985                    Lihue Kuhio Hwy.     LIHC61     CITY
# 1         1  103986                       Lihue Airport     LIHT61  AIRPORT
# 2         2  103987  Schofield Barracks (Military Only)     E13651     CITY
# 3         3  103988                     Molokai Airport     MKKT71  AIRPORT
# 4         4  103989                              Kailua     E13610     CITY
# ...     ...     ...                                 ...        ...      ...
# 4172   4172  108157                           Key Largo     E14128     CITY
# 4173   4173  108158       Florida Keys Marathon Airport     E14186  AIRPORT
# 4174   4174  108159  Boca Chica Naval Air Military Only     E141BC     CITY
# 4175   4175  108160      Key West International Airport     EYWT61  AIRPORT
# 4176   4176  108161                            Key West     E14130     CITY
#
#                        address_1 country                       city state  \
# 0               3-3257 Kuhio Hwy      US                      Lihue    HI
# 1            3276 Hoolimalima Pl      US                      Lihue    HI
# 2     694 Mccormack Ave Bldg 694      US          Schofield Barrack    HI
# 3       Bldg #2 Airport Loop Mkk      US                   Hoolehua    HI
# 4                134a Hamakua Dr      US                     Kailua    HI
# ...                          ...     ...                        ...   ...
# 4172     100149 Overseas Highway      US                  Key Largo    FL
# 4173          9400 Overseas Hwy.      US                   Marathon    FL
# 4174      Bldg A-4203 Midway Ave      US  Key West Naval Airstation    FL
# 4175       3491 S Roosevelt Blvd      US                   Key West    FL
# 4176       2516 N Roosevelt Blvd      US                   Key West    FL
#
#                 phone  postal_code group_branch_number   latitude   longitude  \
# 0     +1 808-241-5580        96766                36EL  21.990878 -159.366127
# 1     +1 844-914-1553        96766                3642  21.979900 -159.350200
# 2     +1 808-671-5399        96786                3651  21.498478 -158.008438
# 3     +1 808-567-6381        96729                36A8  21.156484 -157.098400
# 4     +1 808-261-4282        96734                3610  21.391604 -157.743429
# ...               ...          ...                 ...        ...         ...
# 4172  +1 305-451-3998        33037                4128  25.100639  -80.433584
# 4173  +1 305-289-7630        33050                4186  24.725854  -81.047595
# 4174  +1 305-292-0220        33040                41BC  24.581717  -81.689769
# 4175  +1 844-958-1292        33040                41KE  24.555600  -81.758300
# 4176  +1 305-292-0220        33040                4130  24.563817  -81.775382
#
#          update_timestamp              RunDate     InsertUpdateTime  RunID  \
# 0     2022-03-25 00:00:00  2022-05-03 08:50:05  2022-05-03 08:53:49  46292
# 1     2021-05-03 00:00:00  2022-05-03 08:50:05  2022-05-03 08:53:49  46292
# 2     2022-04-06 00:00:00  2022-05-03 08:50:05  2022-05-03 08:54:09  46292
# 3     2021-10-07 00:00:00  2022-05-03 08:50:05  2022-05-03 08:55:44  46292
# 4     2022-03-25 00:00:00  2022-05-03 08:50:05  2022-05-03 08:55:55  46292
# ...                   ...                  ...                  ...    ...
# 4172  2020-08-27 00:00:00  2022-05-03 08:50:05  2022-05-03 17:05:36  46292
# 4173  2021-10-11 00:00:00  2022-05-03 08:50:05  2022-05-03 17:08:51  46292
# 4174  2022-04-19 00:00:00  2022-05-03 08:50:05  2022-05-03 17:08:52  46292
# 4175  2021-07-13 00:00:00  2022-05-03 08:50:05  2022-05-03 17:08:52  46292
# 4176  2021-07-13 00:00:00  2022-05-03 08:50:05  2022-05-03 17:08:52  46292
#
#            brand
# 0     ENTERPRISE
# 1     ENTERPRISE
# 2     ENTERPRISE
# 3          ALAMO
# 4     ENTERPRISE
# ...          ...
# 4172  ENTERPRISE
# 4173  ENTERPRISE
# 4174  ENTERPRISE
# 4175  ENTERPRISE
# 4176  ENTERPRISE
#
# [4177 rows x 19 columns]

# %% [markdown]
# ## Data Type Conversions

# %%
processed_df = cleaned_df
print("Columns in cleaned_df:", processed_df.columns)
# Out:
# Columns in cleaned_df: Index(['index', 'tid', 'loc_name', 'loc_number', 'loc_type', 'address_1',
#        'country', 'city', 'state', 'phone', 'postal_code',
#        'group_branch_number', 'latitude', 'longitude', 'update_timestamp',
#        'RunDate', 'InsertUpdateTime', 'RunID', 'brand'],
#       dtype='object')

# %% [markdown]
# ## Svaing the Cleaned Dataset

# %%
cleaned_file_path = '../data/cleaned/enterprise_station.csv'
processed_df.to_csv(cleaned_file_path, index=False)

print("\nData Preprocessing Complete. Cleaned data saved to:", cleaned_file_path)
# Out:
# Data Preprocessing Complete. Cleaned data saved to: ../data/cleaned/enterprise_station.csv
